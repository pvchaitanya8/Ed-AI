# %% [markdown]
# ## Dynamic Files - Reset

# %% [markdown]
# ### Practice // MCQ Page

# %%
import json

json_file = r'../dynamic files/Main_pages/Practice_MCQ.json'
with open(json_file, 'r') as file:
    data = json.load(file)

for key in data:
    data[key]["Completed"] = False

with open(json_file, 'w') as file:
    json.dump(data, file, indent=4)

print(json.dumps(data, indent=4))
# Out:
# {
#     "Programming_Fundamentals_000001": {
#         "Title": "Programming_Fundamentals",
#         "Completed": false
#     },
#     "Array_000001": {
#         "Title": "Array",
#         "Completed": false
#     },
#     "Linked_List_000001": {
#         "Title": "Linked_List",
#         "Completed": false
#     },
#     "Stack_000001": {
#         "Title": "Stack",
#         "Completed": false
#     },
#     "Queue_000001": {
#         "Title": "Queue",
#         "Completed": false
#     },
#     "Tree_000001": {
#         "Title": "Tree",
#         "Completed": false
#     },
#     "Graph_000001": {
#         "Title": "Graph",
#         "Completed": false
#     },
#     "Hashing_000001": {
#         "Title": "Hashing",
#         "Completed": false
#     },
#     "Heap_000001": {
#         "Title": "Heap",
#         "Completed": false
#     },
#     "Sort_000001": {
#         "Title": "Sort",
#         "Completed": false
#     },
#     "Search_000001": {
# ...

# %% [markdown]
# ### Practice // Coding Problems Page

# %%
import json

json_file = r'../dynamic files/Main_pages/Practice_Coding_Problems.json'
with open(json_file, 'r') as file:
    data = json.load(file)

for key in data:
    data[key]["Completed"] = False

with open(json_file, 'w') as file:
    json.dump(data, file, indent=4)

print(json.dumps(data, indent=4))
# Out:
# {
#     "prob_arr_00000000001": {
#         "Title": "Concatenation of Array",
#         "Completed": false
#     },
#     "prob_arr_00000000002": {
#         "Title": "Number of Good Pairs",
#         "Completed": false
#     },
#     "prob_arr_00000000003": {
#         "Title": "Two Sum",
#         "Completed": false
#     },
#     "prob_arr_00000000004": {
#         "Title": "Maximum Subarray Sum",
#         "Completed": false
#     },
#     "prob_arr_00000000005": {
#         "Title": "Smallest Subarray with Sum >= K",
#         "Completed": false
#     },
#     "prob_arr_00000000006": {
#         "Title": "Array Sum",
#         "Completed": false
#     },
#     "prob_arr_00000000007": {
#         "Title": "Maximum Sum of Non-Adjacent Elements",
#         "Completed": false
#     },
#     "prob_str_00000000001": {
#         "Title": "Longest Palindromic Substring",
#         "Completed": false
#     },
#     "prob_str_00000000002": {
# ...

# %% [markdown]
# ### Learn Page

# %%
import json

json_file = r'../dynamic files/Main_pages/Learn.json'
with open(json_file, 'r') as file:
    data = json.load(file)

for key in data:
    data[key]["Completed"] = False

with open(json_file, 'w') as file:
    json.dump(data, file, indent=4)

print(json.dumps(data, indent=4))
# Out:
# {
#     "Image Box 1": {
#         "Title": "DSA Introduction",
#         "Completed": false
#     },
#     "Image Box 2": {
#         "Title": "Programming Fundamentals",
#         "Completed": false
#     },
#     "Image Box 3": {
#         "Title": "control structures and functions",
#         "Completed": false
#     },
#     "Image Box 4": {
#         "Title": "Programming Fundamentals",
#         "Completed": false
#     },
#     "Image Box 5": {
#         "Title": "Programming Fundamentals",
#         "Completed": false
#     },
#     "Image Box 6": {
#         "Title": "Programming Fundamentals",
#         "Completed": false
#     },
#     "Image Box 7": {
#         "Title": "Array",
#         "Completed": false
#     },
#     "Image Box 8": {
#         "Title": "Array",
#         "Completed": false
#     },
#     "Image Box 9": {
#         "Title": "LinkedList",
#         "Completed": false
#     },
#     "Image Box 10": {
#         "Title": "LinkedList",
# ...
